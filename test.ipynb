# %%
from PIL import Image
import matplotlib.pyplot as plt 
import numpy as np 
img=Image.open("/opt/data/private/BairdWorkspace/SegResearchToolkit/data/optic_disc_seg/Annotations/H0002.png")
plt.imshow(img)
print(np.unique(img))
# Out:
# [0 1]

# %%
from PIL import Image
import os 
images_list=os.listdir("/opt/data/private/BairdWorkspace/Seg/SegResearchToolkit/output/result/added_prediction")
images=[Image.open("/opt/data/private/BairdWorkspace/Seg/SegResearchToolkit/output/result/added_prediction/"+x) for x in images_list]
gif=images[0]
gif.save("/opt/data/private/BairdWorkspace/Seg/SegResearchToolkit/predict.gif",format="gif",save_all=True,append_images=images[1:])
